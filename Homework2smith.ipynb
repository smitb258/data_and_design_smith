# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
wine = pd.read_csv('Desktop/Data_Design_Python/Data/winemag-data_first150k.csv.zip')

# %%
wine.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150930 entries, 0 to 150929
# Data columns (total 11 columns):
# Unnamed: 0     150930 non-null int64
# country        150925 non-null object
# description    150930 non-null object
# designation    105195 non-null object
# points         150930 non-null int64
# price          137235 non-null float64
# province       150925 non-null object
# region_1       125870 non-null object
# region_2       60953 non-null object
# variety        150930 non-null object
# winery         150930 non-null object
# dtypes: float64(1), int64(2), object(8)
# memory usage: 12.7+ MB

# %%
affordable = wine[wine['price'] < 9]

# %%
affordable.nlargest(5, 'points')
# Out:
#         Unnamed: 0 country                                        description  \
# 19989        19989      US  Pungent aromas of concentrated stone fruits, b...
# 110140      110140      US  With full ripeness, density and concentration,...
# 15428        15428      US  The grapes for this impressive Aussie-style Sh...
# 15429        15429      US  This Châteauneuf-style wine is jammy, with bla...
# 15438        15438      US  This is an astonishing value, especially from ...
#
#                designation  points  price    province              region_1  \
# 19989     Bacchus Vineyard      91    8.0  Washington  Columbia Valley (WA)
# 110140  Winemaker's Select      91    8.0  Washington  Columbia Valley (WA)
# 15428                  NaN      90    6.0  California            California
# 15429                  NaN      90    5.0  California            California
# 15438              Reserve      90    8.0  California          Sonoma Coast
#
# ...

# %%
affordable.nlargest(5, 'points')
# Out:
#         Unnamed: 0 country                                        description  \
# 19989        19989      US  Pungent aromas of concentrated stone fruits, b...
# 110140      110140      US  With full ripeness, density and concentration,...
# 15428        15428      US  The grapes for this impressive Aussie-style Sh...
# 15429        15429      US  This Châteauneuf-style wine is jammy, with bla...
# 15438        15438      US  This is an astonishing value, especially from ...
#
#                designation  points  price    province              region_1  \
# 19989     Bacchus Vineyard      91    8.0  Washington  Columbia Valley (WA)
# 110140  Winemaker's Select      91    8.0  Washington  Columbia Valley (WA)
# 15428                  NaN      90    6.0  California            California
# 15429                  NaN      90    5.0  California            California
# 15438              Reserve      90    8.0  California          Sonoma Coast
#
# ...

# %%
affordable.nsmallest(5, 'points')
# Out:
#        Unnamed: 0    country  \
# 7794         7794  Argentina
# 10001       10001   Portugal
# 10592       10592      Spain
# 11562       11562      Spain
# 18616       18616      Spain
#
#                                              description     designation  \
# 7794   Candied plum and red berry aromas smell like r...  Estate Bottled
# 10001  This is a light, fruity and off-dry wine. It h...             NaN
# 10592  An unclean nose smells cheesy. This is flabby ...             NaN
# 11562  Strange yeasty unfocused aromas are unclean. T...             NaN
# 18616  This smells like compost. It feels hard and cl...           Manon
#
#        points  price          province                       region_1  \
# 7794       80    5.0  Mendoza Province                        Mendoza
# 10001      80    8.0       Vinho Verde                            NaN
# 10592      80    7.0           Levante                       Valencia
# ...

# %%
wine.groupby('country')['variety'].count().nlargest(5)
# Out:
# country
# US        62397
# Italy     23478
# France    21098
# Spain      8268
# Chile      5816
# Name: variety, dtype: int64

# %%
wine['points'].hist()

# %%
wine['points'].describe()
# Out:
# count    150930.000000
# mean         87.888418
# std           3.222392
# min          80.000000
# 25%          86.000000
# 50%          88.000000
# 75%          90.000000
# max         100.000000
# Name: points, dtype: float64

# %% [markdown]
# # Cheapest Wine for Under 18 with the highest ratings.

# %%
affordable = wine[wine['price'] < 18]

# %%
affordable.nlargest(5, 'points')
# Out:
#         Unnamed: 0 country                                        description  \
# 35854        35854      US  This dry Moscato Giallo from Lodi is delicious...
# 140179      140179   Spain  This reserve-level P.X. sets the gold standard...
# 11143        11143   Italy  This gorgeous Chianti Classico boasts lively c...
# 19580        19580      US  A unique balance—9.8% alcohol and 2% residual ...
# 21684        21684      US  Bill Easton doesn't make this dessert wine eve...
#
#                                     designation  points  price    province  \
# 35854                                     Secco      94   16.0  California
# 140179               Cardenal Cisneros Reservas      94   15.0   Andalucia
# 11143                                       NaN      93   16.0     Tuscany
# 19580                         Champoux Vineyard      93   15.0  Washington
# 21684   Muscat a Petits Grains Vin Doux Naturel      93   15.0  California
#
# ...

# %%
u18 = wine[wine['price'] <= 18]

# %%
u18.head()
# Out:
#     Unnamed: 0   country                                        description  \
# 30          30  Bulgaria  This Bulgarian Mavrud presents the nose with s...
# 40          40     Spain  Earthy plum and cherry aromas score points for...
# 54          54        US  There's a lot to like in this nicely priced wh...
# 74          74  Portugal  It is the ripe dark Alicante Bouschet that dom...
# 90          90        US  Bright, light oak shadings dress up this mediu...
#
#    designation  points  price    province              region_1  \
# 30     Bergulé      90   15.0    Bulgaria                   NaN
# 40      Amandi      90   17.0     Galicia         Ribeira Sacra
# 54         NaN      90   18.0  California  Russian River Valley
# 74     Premium      91   15.0    Alentejo                   NaN
# 90         NaN      86   10.0  California            California
#
#             region_2             variety                      winery
# ...

# %%
u18.tail()
# Out:
#         Unnamed: 0 country                                        description  \
# 150902      150902   Chile  This medium weight Chardonnay offered aromas o...
# 150903      150903   Chile  Very light berry and mint aromas open this aus...
# 150904      150904   Chile  A lot of Chilean Cabernets seem to have a dist...
# 150905      150905   Chile  There's not much point in making a reserve-sty...
# 150929      150929   Italy  More Pinot Grigios should taste like this. A r...
#
#            designation  points  price            province    region_1  \
# 150902  Estate Bottled      81   10.0        Maipo Valley         NaN
# 150903             120      81    7.0        Rapel Valley         NaN
# 150904             NaN      81   10.0        Maipo Valley         NaN
# 150905   Prima Reserva      80   13.0        Maipo Valley         NaN
# 150929             NaN      90   15.0  Northeastern Italy  Alto Adige
#
#        region_2             variety         winery
# ...
